# %%
# !pip install -q condacolab
import condacolab
condacolab.install()
# Out:
# ⏬ Downloading https://github.com/jaimergp/miniforge/releases/download/24.11.2-1_colab/Miniforge3-colab-24.11.2-1_colab-Linux-x86_64.sh...
# 📦 Installing...
# 📌 Adjusting configuration...
# 🩹 Patching environment...
# ⏲ Done in 0:00:06
# 🔁 Restarting kernel...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !cp -r /content/drive/MyDrive/project-blue/jersey-number-pipeline /content/jersey-number-pipeline
# !unzip /content/jersey-number-pipeline/data/SoccerNet/test.zip -d /content/jersey-number-pipeline/data/SoccerNet/
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: /content/jersey-number-pipeline/data/SoccerNet/test/images/975/975_488.jpg
#   inflating: /content/jersey-number-pipeline/data/SoccerNet/test/images/975/975_66.jpg
#   inflating: /content/jersey-number-pipeline/data/SoccerNet/test/images/975/975_259.jpg
#   inflating: /content/jersey-number-pipeline/data/SoccerNet/test/images/975/975_517.jpg
#   inflating: /content/jersey-number-pipeline/data/SoccerNet/test/images/975/975_271.jpg
#   inflating: /content/jersey-number-pipeline/data/SoccerNet/test/images/975/975_265.jpg
#   inflating: /content/jersey-number-pipeline/data/SoccerNet/test/images/975/975_2.jpg
#   inflating: /content/jersey-number-pipeline/data/SoccerNet/test/images/975/975_503.jpg
#   inflating: /content/jersey-number-pipeline/data/SoccerNet/test/images/975/975_729.jpg
#   inflating: /content/jersey-number-pipeline/data/SoccerNet/test/images/975/975_715.jpg
# ...

# %%
# !rm -f /content/jersey-number-pipeline/data/SoccerNet/challenge.zip
# !rm -f /content/jersey-number-pipeline/data/SoccerNet/train.zip

# %%
# %cd /content/jersey-number-pipeline
# Out:
# /content/jersey-number-pipeline

# %%
# !python3 setup.py SoccerNet

# %%
# !python3 main.py SoccerNet test

# %%
# !python3 ./scripts/evaluate.py --pred ./out/SoccerNetResults/final_results.json --gt ./data/SoccerNet/test/test_gt.json
# Out:
# ------------------------------
# EVALUATION RESULTS
# ------------------------------
# Total Samples (GT):    1211
# Predictions Provided: 1207
# Correct Predictions:  1049
# Missing Predictions:  4
# ------------------------------
# FINAL ACCURACY:       86.62%
# ------------------------------

# %%
# !rsync -a --delete /content/jersey-number-pipeline/ /content/drive/MyDrive/project-blue/jersey-number-pipeline/
# Out:
# file has vanished: "/content/drive/MyDrive/project-blue/jersey-number-pipeline/out/SoccerNetResults/crops/imgs/.1097_14.jpg.VWNVm5"

# %%
# !python3 main.py SoccerNet test
# Out:
# Generating json for pose
# Done generating json for pose
# Detecting pose

# %%
pip install scipy pandas torchvision gdown

# %%
# !nvidia-smi
# Out:
# Sat Feb 21 17:21:34 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 580.82.07              Driver Version: 580.82.07      CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA A100-SXM4-80GB          Off |   00000000:00:05.0 Off |                    0 |
# | N/A   34C    P0             54W /  400W |       0MiB /  81920MiB |      0%      Default |
# |                                         |                        |             Disabled |
# ...

# %%
ln -sf /usr/local/envs/parseq2/lib/libstdc++.so.6 /lib/x86_64-linux-gnu/libstdc++.so.6

# %%
conda run --live-stream -n parseq2 conda install -y -c conda-forge "libstdcxx-ng>=13"
